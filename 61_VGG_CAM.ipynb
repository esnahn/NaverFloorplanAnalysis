# %%
import tensorflow as tf
import tensorflow.keras.backend as K

from tensorflow.keras.models import Sequential, Model

from tensorflow.keras.layers import (
    Input,
    Dense,
    Reshape,
    Flatten,
    Dropout,
    BatchNormalization,
    Activation,
    ZeroPadding2D,
    LeakyReLU,
    UpSampling2D,
    Conv2D,
    Convolution2D,
    MaxPooling2D,
    Concatenate,
    GaussianNoise,
    GaussianDropout,
    Lambda,
    GlobalAveragePooling2D,
)

from tensorflow.keras.optimizers import Adam

from tensorflow.keras.utils import to_categorical

import h5py
import pickle

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import os
import pathlib

import time

import math

# %%
print("Tensorflow version: ", tf.version.VERSION)  # tf2
print("Keras version: ", tf.keras.__version__)  # 2.2.4-tf

# tf.enable_eager_execution()  # tf2
print("Is eager execution enabled: ", tf.executing_eagerly())
print("Is there a GPU available: ", tf.test.is_gpu_available())
# Out:
# Tensorflow version:  2.1.0
# Keras version:  2.2.4-tf
# Is eager execution enabled:  True
# WARNING:tensorflow:From <ipython-input-2-177a7f55bd9d>:6: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# Is there a GPU available:  True

# %%
path_train_tfrecord = "fp56_train.tfrecord"
path_test_tfrecord = "fp56_test.tfrecord"

# %% [markdown]
# # model save dir

# %%
dir_model = "vgg_cam/"
pathlib.Path(dir_model).mkdir(parents=True, exist_ok=True)

# %%
fp_dim = (56, 56, 6)


def _parse_function(example_proto):
    # Create a description of the features.
    feature_description = {
        "floorplan": tf.io.FixedLenFeature(
            fp_dim, tf.float32, default_value=tf.zeros(fp_dim, tf.float32)
        ),
        "plan_id": tf.io.FixedLenFeature([], tf.string, default_value=""),
        "year": tf.io.FixedLenFeature([], tf.int64, default_value=-1),  # 0~9
        # "sido": tf.FixedLenFeature([], tf.int64, default_value=-1),
        # "norm_area": tf.FixedLenFeature([], tf.float32, default_value=0.0),
        # "num_rooms": tf.FixedLenFeature([], tf.int64, default_value=-1),
        # "num_baths": tf.FixedLenFeature([], tf.int64, default_value=-1),
    }

    # Parse the input tf.Example proto using the dictionary above.
    parsed_example = tf.io.parse_single_example(example_proto, feature_description)

    return parsed_example["floorplan"], parsed_example["year"]

# %%
def _onehot_year(fp, year):
    year_onehot = tf.one_hot(year, 10)  # 1970~4 -> 0, 2015~9 -> 9
    return (fp, year_onehot)

# %%
def create_dataset(filepath):
    # This works with arrays as well
    dataset = tf.data.TFRecordDataset(filepath, compression_type="GZIP")

    # Maps the parser on every filepath in the array. You can set the number of parallel loaders here
    dataset = dataset.map(_parse_function, num_parallel_calls=4)

    ### preprocess the features

    # won't use it. use sparse_categorical_crossentropy instead of categorical_crossentropy.
    #     dataset = dataset.map(_onehot_year, num_parallel_calls=4)

    return dataset

# %%
def VGG16_convolutions():
    if K.image_data_format() == "channels_last":
        input_shape = (fp_dim[0], fp_dim[1], fp_dim[2])
    else:
        input_shape = (fp_dim[2], fp_dim[0], fp_dim[1])

    model = Sequential()
    model.add(GaussianNoise(0.1, input_shape=input_shape))

    model.add(Conv2D(64, (3, 3), activation="relu", name="conv1_1", padding="same"))
    model.add(Conv2D(64, (3, 3), activation="relu", name="conv1_2", padding="same"))
    model.add(MaxPooling2D((2, 2), strides=(1, 1), padding="same"))

    model.add(Conv2D(128, (3, 3), activation="relu", name="conv2_1", padding="same"))
    model.add(Conv2D(128, (3, 3), activation="relu", name="conv2_2", padding="same"))
    model.add(MaxPooling2D((2, 2), strides=(1, 1), padding="same"))

    model.add(Conv2D(256, (3, 3), activation="relu", name="conv3_1", padding="same"))
    model.add(Conv2D(256, (3, 3), activation="relu", name="conv3_2", padding="same"))
    model.add(Conv2D(256, (3, 3), activation="relu", name="conv3_3", padding="same"))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))

    model.add(Conv2D(512, (3, 3), activation="relu", name="conv4_1", padding="same"))
    model.add(Conv2D(512, (3, 3), activation="relu", name="conv4_2", padding="same"))
    model.add(Conv2D(512, (3, 3), activation="relu", name="conv4_3", padding="same"))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))

    model.add(Conv2D(512, (3, 3), activation="relu", name="conv5_1", padding="same"))
    model.add(Conv2D(512, (3, 3), activation="relu", name="conv5_2", padding="same"))
    model.add(Conv2D(512, (3, 3), activation="relu", name="conv5_3", padding="same"))
    return model

# %%
num_classes = 10


def create_model():
    model = VGG16_convolutions()

    model.add(GlobalAveragePooling2D())
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation="softmax"))

    model.compile(
        optimizer="sgd", loss="sparse_categorical_crossentropy", metrics=["accuracy"]
    )
    return model

# %%
callback_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    dir_model + "model-{epoch:02d}-{val_loss:.2f}-{val_accuracy:.1%}.hdf5",
    # save_weights_only=True,
    verbose=1,
)

# %%
callback_stop = tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=20)

# %% [markdown]
# # run

# %%
# .repeat().shuffle(4096).batch(8)

train_dataset = create_dataset(path_train_tfrecord).shuffle(1024).batch(8)
test_dataset = create_dataset(path_test_tfrecord).batch(8)

train_dataset, test_dataset
# Out:
# (<BatchDataset shapes: ((None, 56, 56, 6), (None,)), types: (tf.float32, tf.int64)>,
#  <BatchDataset shapes: ((None, 56, 56, 6), (None,)), types: (tf.float32, tf.int64)>)

# %%
model = create_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gaussian_noise (GaussianNois (None, 56, 56, 6)         0
# _________________________________________________________________
# conv1_1 (Conv2D)             (None, 56, 56, 64)        3520
# _________________________________________________________________
# conv1_2 (Conv2D)             (None, 56, 56, 64)        36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2_1 (Conv2D)             (None, 56, 56, 128)       73856
# _________________________________________________________________
# conv2_2 (Conv2D)             (None, 56, 56, 128)       147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 128)       0
# _________________________________________________________________
# conv3_1 (Conv2D)             (None, 56, 56, 256)       295168
# _________________________________________________________________
# conv3_2 (Conv2D)             (None, 56, 56, 256)       590080
# _________________________________________________________________
# conv3_3 (Conv2D)             (None, 56, 56, 256)       590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 256)       0
# _________________________________________________________________
# conv4_1 (Conv2D)             (None, 28, 28, 512)       1180160
# _________________________________________________________________
# conv4_2 (Conv2D)             (None, 28, 28, 512)       2359808
# _________________________________________________________________
# conv4_3 (Conv2D)             (None, 28, 28, 512)       2359808
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 512)       0
# _________________________________________________________________
# conv5_1 (Conv2D)             (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv5_2 (Conv2D)             (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv5_3 (Conv2D)             (None, 14, 14, 512)       2359808
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 10)                5130
# =================================================================
# Total params: 14,721,546
# Trainable params: 14,721,546
# Non-trainable params: 0
# _________________________________________________________________

# %%
path_best = dir_model + "model-15-1.36.hdf5"
epoch_best = 0  # 0 if starting from fresh

if epoch_best and os.path.exists(path_best):
    model.load_weights(path_best)
    history = model.fit(
        train_dataset,
        epochs=50,
        initial_epoch=epoch_best,
        validation_data=test_dataset,
        callbacks=[callback_checkpoint, callback_stop],
    )
else:
    history = model.fit(
        train_dataset,
        epochs=50,
        validation_data=test_dataset,
        callbacks=[callback_checkpoint, callback_stop],
    )
# Out:
# Epoch 1/50
#    5075/Unknown - 1155s 228ms/step - loss: 1.8163 - accuracy: 0.2780
# Epoch 00001: saving model to vgg_cam/model-01-1.83-31.9%.hdf5
# 5075/5075 [==============================] - 1262s 249ms/step - loss: 1.8163 - accuracy: 0.2780 - val_loss: 1.8276 - val_accuracy: 0.3195
# Epoch 2/50
# 5074/5075 [============================>.] - ETA: 0s - loss: 1.4637 - accuracy: 0.4164
# Epoch 00002: saving model to vgg_cam/model-02-1.48-39.9%.hdf5
# 5075/5075 [==============================] - 1272s 251ms/step - loss: 1.4636 - accuracy: 0.4164 - val_loss: 1.4779 - val_accuracy: 0.3992
# Epoch 3/50
# 5074/5075 [============================>.] - ETA: 0s - loss: 1.3363 - accuracy: 0.4566
# Epoch 00003: saving model to vgg_cam/model-03-1.50-39.2%.hdf5
# 5075/5075 [==============================] - 1272s 251ms/step - loss: 1.3362 - accuracy: 0.4567 - val_loss: 1.4997 - val_accuracy: 0.3915
# Epoch 4/50
# 5074/5075 [============================>.] - ETA: 0s - loss: 1.2741 - accuracy: 0.4780
# Epoch 00004: saving model to vgg_cam/model-04-1.42-43.8%.hdf5
# 5075/5075 [==============================] - 1272s 251ms/step - loss: 1.2742 - accuracy: 0.4780 - val_loss: 1.4247 - val_accuracy: 0.4380
# Epoch 5/50
# 5074/5075 [============================>.] - ETA: 0s - loss: 1.2266 - accuracy: 0.4984
# Epoch 00005: saving model to vgg_cam/model-05-1.47-44.3%.hdf5
# 5075/5075 [==============================] - 1271s 250ms/step - loss: 1.2265 - accuracy: 0.4984 - val_loss: 1.4676 - val_accuracy: 0.4425
# Epoch 6/50
# 5074/5075 [============================>.] - ETA: 0s - loss: 1.1861 - accuracy: 0.5167
# Epoch 00006: saving model to vgg_cam/model-06-1.34-47.0%.hdf5
# 5075/5075 [==============================] - 1270s 250ms/step - loss: 1.1860 - accuracy: 0.5168 - val_loss: 1.3386 - val_accuracy: 0.4696
# Epoch 7/50
# 5074/5075 [============================>.] - ETA: 0s - loss: 1.1509 - accuracy: 0.5252
# Epoch 00007: saving model to vgg_cam/model-07-1.37-47.8%.hdf5
# 5075/5075 [==============================] - 1280s 252ms/step - loss: 1.1507 - accuracy: 0.5252 - val_loss: 1.3712 - val_accuracy: 0.4781
# Epoch 8/50
# 5074/5075 [============================>.] - ETA: 0s - loss: 1.1193 - accuracy: 0.5405
# Epoch 00008: saving model to vgg_cam/model-08-1.31-48.0%.hdf5
# 5075/5075 [==============================] - 1284s 253ms/step - loss: 1.1193 - accuracy: 0.5404 - val_loss: 1.3089 - val_accuracy: 0.4798
# Epoch 9/50
# 5074/5075 [============================>.] - ETA: 0s - loss: 1.0878 - accuracy: 0.5535
# Epoch 00009: saving model to vgg_cam/model-09-1.29-47.8%.hdf5
# 5075/5075 [==============================] - 1296s 255ms/step - loss: 1.0877 - accuracy: 0.5536 - val_loss: 1.2914 - val_accuracy: 0.4778
# Epoch 10/50
# 5074/5075 [============================>.] - ETA: 0s - loss: 1.0571 - accuracy: 0.5646
# Epoch 00010: saving model to vgg_cam/model-10-1.23-50.5%.hdf5
# 5075/5075 [==============================] - 1294s 255ms/step - loss: 1.0570 - accuracy: 0.5646 - val_loss: 1.2324 - val_accuracy: 0.5051
# Epoch 11/50
# 5074/5075 [============================>.] - ETA: 0s - loss: 1.0257 - accuracy: 0.5773
# Epoch 00011: saving model to vgg_cam/model-11-1.18-52.3%.hdf5
# 5075/5075 [==============================] - 1302s 257ms/step - loss: 1.0256 - accuracy: 0.5774 - val_loss: 1.1782 - val_accuracy: 0.5233
# Epoch 12/50
# 5074/5075 [============================>.] - ETA: 0s - loss: 0.9991 - accuracy: 0.5898
# Epoch 00012: saving model to vgg_cam/model-12-1.26-50.3%.hdf5
# 5075/5075 [==============================] - 1308s 258ms/step - loss: 0.9991 - accuracy: 0.5898 - val_loss: 1.2603 - val_accuracy: 0.5029
# Epoch 13/50
# 5074/5075 [============================>.] - ETA: 0s - loss: 0.9689 - accuracy: 0.6051
# Epoch 00013: saving model to vgg_cam/model-13-1.19-51.5%.hdf5
# 5075/5075 [==============================] - 1310s 258ms/step - loss: 0.9688 - accuracy: 0.6051 - val_loss: 1.1886 - val_accuracy: 0.5148
# Epoch 14/50
# 5074/5075 [============================>.] - ETA: 0s - loss: 0.9403 - accuracy: 0.6145
# Epoch 00014: saving model to vgg_cam/model-14-1.27-49.9%.hdf5
# 5075/5075 [==============================] - 1307s 257ms/step - loss: 0.9401 - accuracy: 0.6145 - val_loss: 1.2741 - val_accuracy: 0.4994
# Epoch 15/50
# 5074/5075 [============================>.] - ETA: 0s - loss: 0.9103 - accuracy: 0.6272
# Epoch 00015: saving model to vgg_cam/model-15-1.19-52.8%.hdf5
# 5075/5075 [==============================] - 1285s 253ms/step - loss: 0.9103 - accuracy: 0.6272 - val_loss: 1.1858 - val_accuracy: 0.5283
# Epoch 16/50
# 5074/5075 [============================>.] - ETA: 0s - loss: 0.8782 - accuracy: 0.6428
# Epoch 00016: saving model to vgg_cam/model-16-1.26-52.8%.hdf5
# 5075/5075 [==============================] - 1282s 253ms/step - loss: 0.8781 - accuracy: 0.6428 - val_loss: 1.2559 - val_accuracy: 0.5281
# Epoch 17/50
# 5074/5075 [============================>.] - ETA: 0s - loss: 0.8454 - accuracy: 0.6528
# Epoch 00017: saving model to vgg_cam/model-17-1.17-53.3%.hdf5
# 5075/5075 [==============================] - 1275s 251ms/step - loss: 0.8455 - accuracy: 0.6527 - val_loss: 1.1735 - val_accuracy: 0.5327
# Epoch 18/50
# 5074/5075 [============================>.] - ETA: 0s - loss: 0.8093 - accuracy: 0.6724
# Epoch 00018: saving model to vgg_cam/model-18-1.22-53.1%.hdf5
# 5075/5075 [==============================] - 1278s 252ms/step - loss: 0.8093 - accuracy: 0.6724 - val_loss: 1.2236 - val_accuracy: 0.5311
# Epoch 19/50
# 5074/5075 [============================>.] - ETA: 0s - loss: 0.7753 - accuracy: 0.6869
# Epoch 00019: saving model to vgg_cam/model-19-1.22-52.7%.hdf5
# 5075/5075 [==============================] - 1264s 249ms/step - loss: 0.7753 - accuracy: 0.6869 - val_loss: 1.2217 - val_accuracy: 0.5271
# Epoch 20/50
# 5074/5075 [============================>.] - ETA: 0s - loss: 0.7371 - accuracy: 0.7053
# Epoch 00020: saving model to vgg_cam/model-20-1.28-52.4%.hdf5
# 5075/5075 [==============================] - 1270s 250ms/step - loss: 0.7371 - accuracy: 0.7053 - val_loss: 1.2832 - val_accuracy: 0.5235
# Epoch 21/50
# 5074/5075 [============================>.] - ETA: 0s - loss: 0.6986 - accuracy: 0.7198
# Epoch 00021: saving model to vgg_cam/model-21-1.30-53.0%.hdf5
# 5075/5075 [==============================] - 1276s 251ms/step - loss: 0.6986 - accuracy: 0.7198 - val_loss: 1.3000 - val_accuracy: 0.5298
# Epoch 22/50
# 5074/5075 [============================>.] - ETA: 0s - loss: 0.6581 - accuracy: 0.7366
# Epoch 00022: saving model to vgg_cam/model-22-1.51-50.4%.hdf5
# 5075/5075 [==============================] - 1278s 252ms/step - loss: 0.6581 - accuracy: 0.7366 - val_loss: 1.5058 - val_accuracy: 0.5037
# Epoch 23/50
# 5074/5075 [============================>.] - ETA: 0s - loss: 0.6146 - accuracy: 0.7564
# Epoch 00023: saving model to vgg_cam/model-23-1.95-50.4%.hdf5
# 5075/5075 [==============================] - 1279s 252ms/step - loss: 0.6145 - accuracy: 0.7564 - val_loss: 1.9534 - val_accuracy: 0.5037
# Epoch 24/50
# 5074/5075 [============================>.] - ETA: 0s - loss: 0.5768 - accuracy: 0.7736
# Epoch 00024: saving model to vgg_cam/model-24-1.55-51.4%.hdf5
# 5075/5075 [==============================] - 1280s 252ms/step - loss: 0.5769 - accuracy: 0.7736 - val_loss: 1.5468 - val_accuracy: 0.5136
# Epoch 25/50
# 5074/5075 [============================>.] - ETA: 0s - loss: 0.5351 - accuracy: 0.7895
# Epoch 00025: saving model to vgg_cam/model-25-1.53-53.0%.hdf5
# 5075/5075 [==============================] - 1280s 252ms/step - loss: 0.5350 - accuracy: 0.7895 - val_loss: 1.5311 - val_accuracy: 0.5298
# Epoch 26/50
# 5074/5075 [============================>.] - ETA: 0s - loss: 0.4968 - accuracy: 0.8089
# Epoch 00026: saving model to vgg_cam/model-26-1.64-51.1%.hdf5
# 5075/5075 [==============================] - 1280s 252ms/step - loss: 0.4968 - accuracy: 0.8089 - val_loss: 1.6422 - val_accuracy: 0.5106
# Epoch 27/50
# 5074/5075 [============================>.] - ETA: 0s - loss: 0.4606 - accuracy: 0.8202
# Epoch 00027: saving model to vgg_cam/model-27-1.66-53.8%.hdf5
# 5075/5075 [==============================] - 1281s 252ms/step - loss: 0.4605 - accuracy: 0.8202 - val_loss: 1.6612 - val_accuracy: 0.5378
# Epoch 28/50
# 5074/5075 [============================>.] - ETA: 0s - loss: 0.4267 - accuracy: 0.8377
# Epoch 00028: saving model to vgg_cam/model-28-1.70-53.3%.hdf5
# 5075/5075 [==============================] - 1281s 252ms/step - loss: 0.4267 - accuracy: 0.8377 - val_loss: 1.7048 - val_accuracy: 0.5326
# Epoch 29/50
# 5074/5075 [============================>.] - ETA: 0s - loss: 0.3955 - accuracy: 0.8482
# Epoch 00029: saving model to vgg_cam/model-29-2.03-52.1%.hdf5
# 5075/5075 [==============================] - 1281s 252ms/step - loss: 0.3955 - accuracy: 0.8483 - val_loss: 2.0285 - val_accuracy: 0.5214
# Epoch 30/50
# 5074/5075 [============================>.] - ETA: 0s - loss: 0.3683 - accuracy: 0.8567
# Epoch 00030: saving model to vgg_cam/model-30-1.85-51.2%.hdf5
# 5075/5075 [==============================] - 1281s 252ms/step - loss: 0.3683 - accuracy: 0.8567 - val_loss: 1.8516 - val_accuracy: 0.5123
# Epoch 31/50
# 5074/5075 [============================>.] - ETA: 0s - loss: 0.3414 - accuracy: 0.8712
# Epoch 00031: saving model to vgg_cam/model-31-1.67-54.6%.hdf5
# 5075/5075 [==============================] - 1281s 252ms/step - loss: 0.3414 - accuracy: 0.8712 - val_loss: 1.6691 - val_accuracy: 0.5456
# Epoch 32/50
# 5074/5075 [============================>.] - ETA: 0s - loss: 0.3097 - accuracy: 0.8837
# Epoch 00032: saving model to vgg_cam/model-32-1.93-52.8%.hdf5
# 5075/5075 [==============================] - 1281s 252ms/step - loss: 0.3097 - accuracy: 0.8837 - val_loss: 1.9304 - val_accuracy: 0.5281
# Epoch 33/50
# 5074/5075 [============================>.] - ETA: 0s - loss: 0.2885 - accuracy: 0.8938
# Epoch 00033: saving model to vgg_cam/model-33-2.14-52.6%.hdf5
# 5075/5075 [==============================] - 1281s 252ms/step - loss: 0.2885 - accuracy: 0.8938 - val_loss: 2.1392 - val_accuracy: 0.5260
# Epoch 34/50
# 5074/5075 [============================>.] - ETA: 0s - loss: 0.2693 - accuracy: 0.8992
# Epoch 00034: saving model to vgg_cam/model-34-2.16-53.0%.hdf5
# 5075/5075 [==============================] - 1281s 252ms/step - loss: 0.2692 - accuracy: 0.8993 - val_loss: 2.1564 - val_accuracy: 0.5299
# Epoch 35/50
# 5074/5075 [============================>.] - ETA: 0s - loss: 0.2442 - accuracy: 0.9114
# Epoch 00035: saving model to vgg_cam/model-35-2.26-53.3%.hdf5
# 5075/5075 [==============================] - 1281s 252ms/step - loss: 0.2442 - accuracy: 0.9114 - val_loss: 2.2560 - val_accuracy: 0.5335
# Epoch 36/50
# 5074/5075 [============================>.] - ETA: 0s - loss: 0.2287 - accuracy: 0.9168
# Epoch 00036: saving model to vgg_cam/model-36-2.37-52.9%.hdf5
# 5075/5075 [==============================] - 1282s 253ms/step - loss: 0.2287 - accuracy: 0.9168 - val_loss: 2.3739 - val_accuracy: 0.5287
# Epoch 37/50
# 5074/5075 [============================>.] - ETA: 0s - loss: 0.2106 - accuracy: 0.9225
# Epoch 00037: saving model to vgg_cam/model-37-2.62-53.3%.hdf5
# 5075/5075 [==============================] - 1281s 252ms/step - loss: 0.2105 - accuracy: 0.9225 - val_loss: 2.6229 - val_accuracy: 0.5333

# %%
history.history
# Out:
# {'loss': [1.8162978943348331,
#   1.4635991291833268,
#   1.3362321493349507,
#   1.2741757292742564,
#   1.2264919695851133,
#   1.186024851397086,
#   1.1507806714265016,
#   1.119309566991013,
#   1.0876969628553919,
#   1.0570432796616984,
#   1.0256374557767984,
#   0.9991143535520004,
#   0.9688518497502137,
#   0.9401483448623548,
#   0.9102872164239202,
#   0.8780909352328626,
#   0.8454820460959358,
#   0.8092848961224338,
#   0.7753078669178949,
#   0.7370844810395072,
#   0.6985614552739348,
#   0.6580675742025299,
#   0.6145530962747002,
#   0.5768494394976398,
#   0.5350521280238432,
#   0.4967964432391811,
#   0.46053187873514906,
#   0.42668259218678334,
#   0.39550364380784503,
#   0.3682810392729146,
#   0.34136750161174495,
#   0.3096840356207254,
#   0.28847593629735113,
#   0.2692262731716117,
#   0.24416366183208096,
#   0.22865911675981732,
#   0.21053600871395625],
#  'accuracy': [0.27796936,
#   0.4164491,
#   0.45667273,
#   0.47802848,
#   0.4984482,
#   0.51677424,
#   0.5251983,
#   0.5404453,
#   0.5535987,
#   0.5646337,
#   0.5773683,
#   0.589832,
#   0.60507905,
#   0.61453766,
#   0.62724763,
#   0.64281493,
#   0.6527415,
#   0.6723977,
#   0.6869304,
#   0.7052564,
#   0.71976453,
#   0.7366126,
#   0.75641656,
#   0.7736095,
#   0.78952163,
#   0.80888224,
#   0.82018816,
#   0.8377014,
#   0.8482684,
#   0.85671705,
#   0.87117594,
#   0.8837381,
#   0.89383715,
#   0.8992561,
#   0.9113503,
#   0.9168432,
#   0.92248386],
#  'val_loss': [1.8276090505405607,
#   1.4778723998215935,
#   1.4996511626806552,
#   1.4247261519114045,
#   1.46764188774035,
#   1.3385755635902916,
#   1.3711647873045298,
#   1.308884818505036,
#   1.2914354372476387,
#   1.2324052438288062,
#   1.1782387287387595,
#   1.2603415379913365,
#   1.1885713476999396,
#   1.2741120515118083,
#   1.1857899964726109,
#   1.2558605213462073,
#   1.1734699930103731,
#   1.2236379873911853,
#   1.2216807436738117,
#   1.283174069360664,
#   1.2999641219464184,
#   1.5057814580460898,
#   1.9534249508955193,
#   1.546836470084785,
#   1.5311400687126033,
#   1.6422120019756474,
#   1.6612404686921178,
#   1.704755053038353,
#   2.0284658899139565,
#   1.8515558746850154,
#   1.6690863017158701,
#   1.9304001867860268,
#   2.139214891654477,
#   2.1564442400906203,
#   2.255996604095231,
#   2.3738542128211177,
#   2.6229495651902406],
#  'val_accuracy': [0.3194531,
#   0.39921275,
#   0.39154753,
#   0.43795317,
#   0.44251087,
#   0.46964988,
#   0.47814378,
#   0.47980112,
#   0.47783303,
#   0.50507563,
#   0.5233064,
#   0.50290036,
#   0.5148125,
#   0.4993785,
#   0.5282784,
#   0.5280713,
#   0.53273255,
#   0.5310752,
#   0.527139,
#   0.52351356,
#   0.5298322,
#   0.50372905,
#   0.50372905,
#   0.51356953,
#   0.5298322,
#   0.5105656,
#   0.5378082,
#   0.53262895,
#   0.5214419,
#   0.5123265,
#   0.545577,
#   0.5280713,
#   0.5259996,
#   0.5299358,
#   0.53345764,
#   0.5286928,
#   0.53325045]}

# %%
df_hist = pd.DataFrame(
    history.history,
    index=range(epoch_best + 1, epoch_best + len(history.history["loss"]) + 1),
)
df_hist.index.name = "epoch"

# %%
df_hist
# Out:
#            loss  accuracy  val_loss  val_accuracy
# epoch
# 1      1.816298  0.277969  1.827609      0.319453
# 2      1.463599  0.416449  1.477872      0.399213
# 3      1.336232  0.456673  1.499651      0.391548
# 4      1.274176  0.478028  1.424726      0.437953
# 5      1.226492  0.498448  1.467642      0.442511
# 6      1.186025  0.516774  1.338576      0.469650
# 7      1.150781  0.525198  1.371165      0.478144
# 8      1.119310  0.540445  1.308885      0.479801
# 9      1.087697  0.553599  1.291435      0.477833
# 10     1.057043  0.564634  1.232405      0.505076
# 11     1.025637  0.577368  1.178239      0.523306
# 12     0.999114  0.589832  1.260342      0.502900
# 13     0.968852  0.605079  1.188571      0.514813
# 14     0.940148  0.614538  1.274112      0.499379
# 15     0.910287  0.627248  1.185790      0.528278
# 16     0.878091  0.642815  1.255861      0.528071
# 17     0.845482  0.652741  1.173470      0.532733
# 18     0.809285  0.672398  1.223638      0.531075
# 19     0.775308  0.686930  1.221681      0.527139
# 20     0.737084  0.705256  1.283174      0.523514
# 21     0.698561  0.719765  1.299964      0.529832
# 22     0.658068  0.736613  1.505781      0.503729
# 23     0.614553  0.756417  1.953425      0.503729
# 24     0.576849  0.773610  1.546836      0.513570
# 25     0.535052  0.789522  1.531140      0.529832
# 26     0.496796  0.808882  1.642212      0.510566
# 27     0.460532  0.820188  1.661240      0.537808
# 28     0.426683  0.837701  1.704755      0.532629
# 29     0.395504  0.848268  2.028466      0.521442
# 30     0.368281  0.856717  1.851556      0.512326
# 31     0.341368  0.871176  1.669086      0.545577
# 32     0.309684  0.883738  1.930400      0.528071
# 33     0.288476  0.893837  2.139215      0.526000
# 34     0.269226  0.899256  2.156444      0.529936
# 35     0.244164  0.911350  2.255997      0.533458
# 36     0.228659  0.916843  2.373854      0.528693
# 37     0.210536  0.922484  2.622950      0.533250

# %%
path_hist = dir_model + "history.csv"
df_hist.to_csv(path_hist, mode="a", header=not os.path.exists(path_hist))
